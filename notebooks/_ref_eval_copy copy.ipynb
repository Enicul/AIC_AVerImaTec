# %%
from templates import evid_evaluation_joint
import json

# %%
json.load(open("/mnt/data/factcheck/averimatec/submissions/submission_concat.json", "r"))

# %%
# run /mnt/personal/ullriher/aic_averimatec/prepare_submission/eval_offline.py

# !python3 prepare_submission/eval_offline.py --root_dir /mnt/data/factcheck/averimatec --pred_file_path "/mnt/data/factcheck/averimatec/submissions/val_evtext2.json" --cache_dir /mnt/personal/ullriher/.cache/huggingface/models --save_num 7
