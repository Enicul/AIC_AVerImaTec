# %%
from templates import evid_evaluation_joint
import json

# %%
json.load(open("/mnt/personal/ullriher/aic_averimatec/submission_test_concat.json", "r"))

# %%
len(json.load(open("/mnt/personal/ullriher/aic_averimatec/submission_test_concat.json", "r")))

# %%
# run /mnt/personal/ullriher/aic_averimatec/prepare_submission/eval_offline.py

# !python3 prepare_submission/eval_offline.py --root_dir /mnt/data/factcheck/averimatec --pred_file_path "/mnt/personal/ullriher/aic_averimatec/submission_test_concat.json" --save_num 420 --cache_dir /mnt/personal/ullriher/.cache/huggingface/models
